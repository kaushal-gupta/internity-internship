# %%
import pandas as pd

# %%
data = pd.read_csv('Automobile_data.csv')

# %% [markdown]
# **<font size="5">Question 1</font>**

# %%
data.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
data.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# **<font size="5">Question 2</font>**

# %%
data.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
data['price'].fillna('NaN')
# Out:
# 0     13495
# 1     16500
# 2     16500
# 3     13950
# 4     17450
# 5     15250
# 6     18920
# 7     16430
# 8     16925
# 9     20970
# 10    30760
# 11    41315
# 12    36880
# 13     5151
# 14     6295
# 15     6575
# 16     6377
# 17     6229
# 18     7295
# 19    12945
# 20    10345
# 21     6785
# 22      NaN
# 23      NaN
# 24    32250
# 25    35550
# 26    36000
# 27     5195
# 28     6095
# 29     6795
#       ...
# 31    18344
# 32    25552
# 33    28248
# 34    40960
# 35    45400
# 36     5389
# 37     6189
# 38     6989
# 39     8189
# 40     7099
# 41     6649
# 42     6849
# 43     7349
# 44    13499
# 45    34028
# 46    37028
# 47      NaN
# 48     5348
# 49     6338
# 50     6488
# 51     6918
# 52     7898
# 53     8778
# 54    15750
# 55     7775
# 56     7975
# 57     7995
# 58     9995
# 59    12940
# 60    13415
# Name: price, Length: 61, dtype: object

# %% [markdown]
# **<font size="5">Question 3</font>**

# %%
maxi = data['price'].max()
for i in range(0,61):
    if data['price'][i]==maxi:
        print(data['company'][i])
        print(data['price'][i])
# Out:
# mercedes-benz
# 45400.0

# %% [markdown]
# **<font size="5">Question 4</font>**

# %%
for i in range(61):
    if data['company'][i]=='toyota':
        print(data.iloc[i,:].values)
# Out:
# [66 'toyota' 'hatchback' 95.7 158.7 'ohc' 'four' 62 35 5348.0]
# [67 'toyota' 'hatchback' 95.7 158.7 'ohc' 'four' 62 31 6338.0]
# [68 'toyota' 'hatchback' 95.7 158.7 'ohc' 'four' 62 31 6488.0]
# [69 'toyota' 'wagon' 95.7 169.7 'ohc' 'four' 62 31 6918.0]
# [70 'toyota' 'wagon' 95.7 169.7 'ohc' 'four' 62 27 7898.0]
# [71 'toyota' 'wagon' 95.7 169.7 'ohc' 'four' 62 27 8778.0]
# [79 'toyota' 'wagon' 104.5 187.8 'dohc' 'six' 156 19 15750.0]

# %% [markdown]
# **<font size="5">Question 5</font>**

# %%
data['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# mitsubishi       4
# audi             4
# mercedes-benz    4
# volkswagen       4
# porsche          3
# honda            3
# chevrolet        3
# isuzu            3
# jaguar           3
# alfa-romero      3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %% [markdown]
# **<font size="5">Question 6</font>**

# %%
data_unique = data['company'].unique()
data_unique
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mitsubishi',
#        'nissan', 'porsche', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
for j in range(16):
    for i in range(61):
        if data['company'][i]==data_unique[j]:
            list_price=data['price'][i]
    print(data_unique[j],"-->",list_price.max())
# Out:
# alfa-romero --> 16500.0
# audi --> 18920.0
# bmw --> 36880.0
# chevrolet --> 6575.0
# dodge --> 6229.0
# honda --> 10345.0
# isuzu --> nan
# jaguar --> 36000.0
# mazda --> 18344.0
# mercedes-benz --> 45400.0
# mitsubishi --> 8189.0
# nissan --> 13499.0
# porsche --> nan
# toyota --> 15750.0
# volkswagen --> 9995.0
# volvo --> 13415.0

# %% [markdown]
# **<font size="5">Question 7</font>**

# %%
for j in range(16):
    for i in range(61):
        if data['company'][i]==data_unique[j]:
            list_price=data['average-mileage'][i]
    print(data_unique[j],"-->",list_price.mean())
# Out:
# alfa-romero --> 19.0
# audi --> 19.0
# bmw --> 15.0
# chevrolet --> 38.0
# dodge --> 31.0
# honda --> 25.0
# isuzu --> 38.0
# jaguar --> 13.0
# mazda --> 31.0
# mercedes-benz --> 14.0
# mitsubishi --> 25.0
# nissan --> 19.0
# porsche --> 17.0
# toyota --> 19.0
# volkswagen --> 26.0
# volvo --> 23.0

# %% [markdown]
# **<font size="5">Question 8</font>**

# %%
data.sort_values(['price'])
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 13     16      chevrolet    hatchback        88.4   141.1         ohc
# 27     36          mazda    hatchback        93.1   159.1         ohc
# 48     66         toyota    hatchback        95.7   158.7         ohc
# 36     49     mitsubishi    hatchback        93.7   157.3         ohc
# 28     37          mazda    hatchback        93.1   159.1         ohc
# 37     50     mitsubishi    hatchback        93.7   157.3         ohc
# 17     20          dodge    hatchback        93.7   157.3         ohc
# 14     17      chevrolet    hatchback        94.5   155.9         ohc
# 49     67         toyota    hatchback        95.7   158.7         ohc
# 16     19          dodge    hatchback        93.7   157.3         ohc
# 50     68         toyota    hatchback        95.7   158.7         ohc
# 15     18      chevrolet        sedan        94.5   158.8         ohc
# ...

# %% [markdown]
# **<font size="5">Question 9</font>**

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
data_g = pd.DataFrame.from_dict(GermanCars)
data_j = pd.DataFrame.from_dict(japaneseCars)

# %%
data_con = pd.concat([data_g,data_j])

# %%
index=[0,1,2,3,4,5,6,7]
data_con['index']=index

# %%
data_con.set_index('index')
# Out:
#            Company   Price
# index
# 0             Ford   23845
# 1         Mercedes  171995
# 2              BMV  135925
# 3             Audi   71400
# 4           Toyota   29995
# 5            Honda   23600
# 6           Nissan   61500
# 7      Mitsubishi    58900

# %% [markdown]
# **<font size="5">Question 10</font>**

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %%
data_c = pd.DataFrame.from_dict(Car_Price)
data_j = pd.DataFrame.from_dict(car_Horsepower)

# %%
pd.merge(data_c,data_j)
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %% [markdown]
# **<font size="5">Competed! Thanks.</font>**
